# %% [markdown]
# <a href="https://colab.research.google.com/github/AswinXBEAST/OpenImageV4download/blob/main/openImage_downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 23.69 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# !pip3 install -r /content/OIDv4_ToolKit/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 67.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 47.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 17.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
# ...

# %% [markdown]
# Go to classes.txt to change the classes [instead of "Boy Girl" you can add your need dataset | and in --type_csv u can keep "train", "test", or "valdation" according your needs

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes  Boy Girl --type_csv train --limit 50
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Boy.
#    [ERROR] | Missing the train-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...100%, 1138 MB, 35200 KB/s, 33 seconds passed
# ...

# %%
# !zip -r /content/file.zip /content/OID/Dataset/train
# Out:
#   adding: content/OID/Dataset/train/ (stored 0%)
#   adding: content/OID/Dataset/train/Boy/ (stored 0%)
#   adding: content/OID/Dataset/train/Boy/c5945f771eb8b4f0.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Boy/5c2a4f50aba53305.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Boy/0486fe7a8ac299dd.jpg (deflated 1%)
#   adding: content/OID/Dataset/train/Boy/6235b11ab5841d1c.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Boy/61b3058f7cb9ef5c.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Boy/9df83e665e878f3c.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Boy/61e1261d69457fad.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Boy/321858f348f25d39.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Boy/ee2d948d01cd83a6.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Boy/11454825bab80b32.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Boy/072d4c181040d5cd.jpg (deflated 0%)
# ...
